# %% [markdown]
# # **Project Name**    -  Hotel Booking EDA

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**  Uday Kumar
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# # Exploring Hotel Booking Dataset
#
# **Objective:**
# The objective of this project is to analyze a hotel booking dataset, comprising information from both city and resort hotels, and uncover key factors influencing bookings. The analysis aims to provide insights into optimal booking strategies, pricing considerations, and factors contributing to special requests.
#
# **Key Steps:**
# 1. **Exploratory Data Analysis (EDA):**
# **Data Inspection:** Examine dataset structure, identify variables, and handle missing values.
# **Descriptive Statistics:** Calculate basic statistics for key variables.
# **Time-based Analysis:** Explore booking patterns over time (months, seasons, events).
# **Booking Channels:** Analyze sources or channels of bookings.
#
# 2. **Visualization:**
# **Heatmaps and Correlation Analysis:** Visualize feature correlations.
# Booking Trends: Create time series plots to visualize temporal booking patterns.
# **Geographical Analysis:** Explore if the hotel location influences bookings.
# Recommendations:
# **Optimal Booking Strategies:** Provide insights on the best time to book for favorable rates.
# Operational Improvements: Suggest operational enhancements based on factors consistently associated with special requests.
# Deliverables:
# Detailed report documenting findings, insights, and recommendations.
# Visualizations supporting key analysis points.
# Predictive models for special requests and daily rates.
# Benefits:
# Empower hotels with actionable insights for strategic decision-making.
# Enhance customer experience through targeted services.
# Optimize operational efficiency based on data-driven recommendations.
# By conducting a thorough analysis of the hotel booking dataset, this project aims to contribute valuable insights that can inform business strategies and improve overall hotel performance.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Efficiently explore a hotel booking dataset to uncover patterns, trends, and influential factors. Address challenges in understanding temporal variations, booking channels, and handling missing data. The goal is to provide a concise yet comprehensive overview to inform subsequent analyses and decision-making**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Derive actionable insights from a hotel booking dataset to optimize booking strategies, pricing, enhance guest experience, and improve operational efficiency. The goal is to empower hotels with data-driven decisions for improved customer satisfaction and business performance.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
file_path = "/content/drive/MyDrive/input/Hotel Bookings.csv"

df = pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate values in the dataset: {duplicate_count}")
# Out:
# Number of duplicate values in the dataset: 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values_count = df.isnull().sum()
print("Number of missing values in each column:")
print(missing_values_count)
# Out:
# Number of missing values in each column:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# ...

# %%
# Visualizing the missing values
plt.figure(figsize=(10, 6))
missing_values_count.plot(kind='bar', color='skyblue')
plt.title('Missing Values in Each Column')
plt.xlabel('Columns')
plt.ylabel('Number of Missing Values')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Our Dataset has **119390 Rows** and **32 Columns**.
#
# It has **31994 duplicate values**.
#
# "There are missing values in the following columns: **'children' (4 missing values), 'country' (488 missing values), 'agent' (16,340 missing values), and 'company' (112,593 missing values)**."
#
# From here we can remove the duplicates and drop the column('agent' and 'company')

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The summary statistics table for various columns in the dataset gives following information:
#
# About **37.04%** of bookings were canceled.
#
# The average lead time is approximately **104 days**, with a maximum lead time of **737 days**.
#
# Most entries are from the year **2016**.
#
# On average, guests stay for about **0.93** weekend nights.
#
# The average stay during weekdays is approximately **2.50 nights**.
#
# On average, only **0.79%** of guests are repeated guests.
#
# Guests make an average of **0.57** special requests.
#
# These statistics provide a quick overview of the central tendency and variability in the dataset.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unique_values = df.nunique().sort_values(ascending = True)

print("Unique values for each variable:")
unique_values
# Out:
# Unique values for each variable:
# hotel                                2
# is_canceled                          2
# is_repeated_guest                    2
# arrival_date_year                    3
# deposit_type                         3
# reservation_status                   3
# customer_type                        4
# required_car_parking_spaces          5
# meal                                 5
# babies                               5
# distribution_channel                 5
# children                             5
# total_of_special_requests            6
# market_segment                       8
# reserved_room_type                  10
# arrival_date_month                  12
# assigned_room_type                  12
# adults                              14
# previous_cancellations              15
# stays_in_weekend_nights             17
# booking_changes                     21
# arrival_date_day_of_month           31
# stays_in_week_nights                35
# ...

# %%
# Check Unique Values for each variable.
for col in df.columns:
    unique_values = df[col].nunique()
    if unique_values < 10:
        print(f"Unique values for {col}:", df[col].unique())
        print()
# Out:
# Unique values for hotel: ['Resort Hotel' 'City Hotel']
#
# Unique values for is_canceled: [0 1]
#
# Unique values for arrival_date_year: [2015 2016 2017]
#
# Unique values for children: [ 0.  1.  2. 10.  3. nan]
#
# Unique values for babies: [ 0  1  2 10  9]
#
# Unique values for meal: ['BB' 'FB' 'HB' 'SC' 'Undefined']
#
# Unique values for market_segment: ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
#
# Unique values for distribution_channel: ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
#
# Unique values for is_repeated_guest: [0 1]
#
# Unique values for deposit_type: ['No Deposit' 'Refundable' 'Non Refund']
#
# Unique values for customer_type: ['Transient' 'Contract' 'Transient-Party' 'Group']
#
# Unique values for required_car_parking_spaces: [0 1 2 8 3]
#
# Unique values for total_of_special_requests: [0 1 3 2 4 5]
#
# Unique values for reservation_status: ['Check-Out' 'Canceled' 'No-Show']

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ### <b> Cleaning data </b>
#
# Cleaning data is crucial step before EDA as it will remove the ambigous data that can affect the outcome of EDA.
#
# While cleaning data we will perform following steps: \
# 1) Remove duplicate rows  \
# 2) Handling missing values.  \
# 3) Convert columns to appropriate datatypes.  \
# 4) Adding impoertant columns

# %% [markdown]
# ### <b> Step 1: Removing duplicate rows if any </b>

# %%
df[df.duplicated()].shape   # Show no. of rows of duplicate rows duplicate rows
# Out:
# (31994, 32)

# %%
# Dropping duplicate values
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# ### <b> Step2: Handling missing values. </b>

# %%
# Columns having missing values.
df.isnull().sum().sort_values(ascending = False)[:6]
# Out:
# company               82137
# agent                 12193
# country                 452
# children                  4
# reserved_room_type        0
# assigned_room_type        0
# dtype: int64

# %% [markdown]
# Since, company and agent columns have comany number and agent numbers as data. There may be some cases when customer didnt booked hotel via any agent or via any company. So in that case values can be null under these columns.
# We will replace null values by 0 in these columns

# %%
# Handling Missing Values
df[['company','agent']] = df[['company','agent']].fillna(0)

# %%
df['children'].unique()
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %% [markdown]
# This column 'children' has 0 as value which means 0 children were present in group of customers who made that transaction.
# So, 'nan' values are the missing values due to error of recording data.
#
# We will replace the null values under this column with mean value of children.

# %%
# Handling Missing Values
df['children'].fillna(df['children'].mean(), inplace = True)

# %% [markdown]
# Next column with missing value is 'country'. This column represents the country of oriigin of customer.
# Since, this column has datatype of string. We will replace the missing value with the mode of 'country' column.

# %%
df['country'].fillna('others', inplace = True)

# %%
# Checking if all null values are removed
df.isnull().sum().sort_values(ascending = False)[:6]
# Out:
# hotel                          0
# is_canceled                    0
# reservation_status             0
# total_of_special_requests      0
# required_car_parking_spaces    0
# adr                            0
# dtype: int64

# %% [markdown]
# There are some rows with total number of adults, children or babies equal to zero. So we will remove such rows.

# %%
df[df['adults']+df['babies']+df['children'] == 0].shape
# Out:
# (166, 32)

# %%
df.drop(df[df['adults']+df['babies']+df['children'] == 0].index, inplace = True)

# %% [markdown]
# ### <b> Step 3: Converting columns to appropriate datatypes. </b>

# %%
# Converting datatype of columns 'children', 'company' and 'agent' from float to int.
df[['children', 'company', 'agent']] = df[['children', 'company', 'agent']].astype('int64')

# %%
# changing datatype of column 'reservation_status_date' to data_type.
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format = '%Y-%m-%d')

# %% [markdown]
# ### <b> Step 4: Adding important columns. </b>

# %%
# Adding total staying days in hotels
df['total_stay'] = df['stays_in_weekend_nights']+df['stays_in_week_nights']

# Adding total people num as column, i.e. total people num = num of adults + children + babies
df['total_people'] = df['adults']+df['children']+df['babies']

# %% [markdown]
# We are adding this column so that we can analyse the stay length at hotels.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The manipulations done above are...
#
# **Removing Duplicate Values:** There were 31994 duplicate rows so they were removed from the data.This is important for various analysis, especially when dealing with unique identifiers.
#
# **Handling Missing Values:** Since, company and agent columns have comany number and agent numbers as data. There may be some cases when customer didnt booked hotel via any agent or via any company. So in that case values can be null under these columns. We will replace null values by 0 in these columns.  \
# This column 'children' has 0 as value which means 0 children were present in group of customers who made that transaction.
# So, 'nan' values are the missing values due to error of recording data.
#
# We will replace the null values under this column with mean value of children. \
# Next column with missing value is 'country'. This column represents the country of oriigin of customer.
# Since, this column has datatype of string. We will replace the missing value with the mode of 'country' column. \
#
# **Converting columns to appropriate datatypes:** There are some rows with total number of adults, children or babies equal to zero. So we will remove such rows.
#
#  **Adding important columns:** We have added the 'total_stay', 'total_people' columns so that we can analyse the stay length at hotels.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
num_df = df[['lead_time','previous_cancellations','previous_bookings_not_canceled','booking_changes','days_in_waiting_list','adr','required_car_parking_spaces','total_of_special_requests','total_stay','total_people']]

# %%
#correlation matrix
corrmat = num_df.corr()
f, ax = plt.subplots(figsize=(12, 7))
sns.heatmap(corrmat,annot = True,fmt='.2f', annot_kws={'size': 10},  vmax=.8, square=True);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Lets first find the correlation between the numerical data.
#
# Since, columns like 'is_cancelled', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'is_repeated_guest', 'company', 'agent' are categorical data having numerical type. So we wont need to check them for correlation

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1) Total stay length and lead time have slight correlation. This may means that for longer hotel stays people generally plan little before the the actual arrival.
#
# 2) adr is slightly correlated with total_people, which makes sense as more no. of people means more revenue, therefore more adr.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# **Optimizing Marketing for Longer Stays:**
#
# Insight: Longer stays are correlated with shorter lead times.
# Positive Impact: The hotel can tailor marketing strategies to target guests planning longer stays closer to the arrival date, potentially increasing bookings.
#
# **Guiding Pricing for Group Bookings:**
#
# Insight: ADR is correlated with the total number of people in a booking.
# Positive Impact: Understanding this correlation can guide pricing strategies and marketing efforts for group bookings, leading to higher revenue.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize = (12,6))
sns.scatterplot(y = 'adr', x = 'total_stay', data = df)
plt.show()

# %% [markdown]
# We notice that there is an outlier in adr, so we will remove that for better scatter plot

# %%
df.drop(df[df['adr'] > 5000].index, inplace = True)

# %%
plt.figure(figsize = (12,6))
sns.scatterplot(y = 'adr', x = 'total_stay', data = df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plot is taken to see how does length of stay affects the adr.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We notice that there is an outlier in adr, so we removed that for better scatter plot
#
# From the scatter plot we can see that as length of tottal_stay increases the adr decreases. This means for longer stay, the better deal for customer can be finalised.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# Better Deals for Longer Stays:
# Positive Impact: Offering better deals for longer stays can attract more customers and increase bookings.
#
# **Potential Negative Growth:**
#
# Causation vs. Correlation:
# Consideration: Scatter plot shows correlation but not necessarily causation. Offering better deals may not always lead to increased bookings; other factors should be considered.

# %%
# Chart - 3 visualization code
df['is_canceled'].value_counts().plot.bar()
plt.title("Distribution of Cancellations")
plt.xlabel('Booking Status (0: Not Canceled, 1: Canceled)')
plt.xticks(rotation=0)
plt.ylabel("Numbers of Bookings")
plt.show()

# %% [markdown]
# #### Chart - 3

# %%
grouped_by_hotel = df.groupby('hotel')
d1 = pd.DataFrame((grouped_by_hotel.size()/df.shape[0])*100).reset_index().rename(columns = {0:'Booking %'})      #Calculating percentage
plt.figure(figsize = (4,3))
sns.barplot(x = d1['hotel'], y = d1['Booking %'] )
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# i picked this chart to see What is percentage of bookings in each hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart it is clear that Booking in City Hotel more than 60% and Resort Hotel less than 40%.
#
# Avg adr of Resort hotel is slightly lower than that of City hotel. Hence, City hotel seems to be making slightly more revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Insights:**
# The chart indicates that more than 60% of bookings are in the City Hotel, while the Resort Hotel accounts for less than 40%.
#
# **Positive Impact:**
# Optimizing marketing for the City Hotel can enhance occupancy and revenue. Tailoring services based on hotel types can improve guest satisfaction.
#
# **Potential Negative Growth:**
# Over-reliance on the City Hotel may pose risks to the business, especially if demand in the city fluctuates. Neglecting marketing for the Resort Hotel could lead to missed revenue opportunities.
#
# **Mitigation:**
# Diversifying marketing efforts and conducting regular market analysis can reduce dependency risks and ensure adaptability to changing customer preferences.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
d2 = grouped_by_hotel['lead_time'].median().reset_index().rename(columns = {'lead_time':'median_lead_time'})
plt.figure(figsize = (8,5))
sns.barplot(x = d2['hotel'], y = d2['median_lead_time'] )
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To know Which hotel has higher lead time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotel has slightly higher median lead time. Also median lead time is significantly higher in each case, this means customers generally plan their hotel visits way to early.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Not that much important

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
not_canceled = df[df['is_canceled'] == 0]
s1 = not_canceled[not_canceled['total_stay'] < 15]
plt.figure(figsize = (10,5))
sns.countplot(x = s1['total_stay'], hue = s1['hotel'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# What is preferred stay in each hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most common stay length is less than 4 days and generally people prefer City hotel for short stay, but for long stays, Resort Hotel is preferred.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The most common stay length is less than 4 days, with a trend of preferring City hotels for short stays and Resort hotels for longer durations. This presents opportunities for tailored services and targeted marketing campaigns based on stay length preferences, potentially enhancing guest satisfaction and attracting a diverse customer base. However, optimizing resource allocation and staying agile in response to changing customer preferences and competitive dynamics are crucial to avoid potential negative impacts on growth.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
d5 = pd.DataFrame(grouped_by_hotel['days_in_waiting_list'].agg(np.mean).reset_index().rename(columns = {'days_in_waiting_list':'avg_waiting_period'}))
plt.figure(figsize = (8,5))
sns.barplot(x = d5['hotel'], y = d5['avg_waiting_period'] )
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To know Which hotel has longer waiting time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotel has significantly longer waiting time, hence City Hotel is much busier than Resort Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights:
# City hotels experience significantly longer waiting times, indicating higher demand and busier operations compared to Resort hotels. This insight suggests the need for efficient management strategies in City hotels to handle the increased demand and waiting times effectively. It could also open opportunities for implementing measures to streamline processes and enhance customer satisfaction during peak periods. However, careful planning and resource allocation are essential to prevent potential negative impacts on customer experience and overall business growth.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Selecting and counting number of cancelled bookings for each hotel.
cancelled_data = df[df['is_canceled'] == 1]
cancel_grp = cancelled_data.groupby('hotel')
D1 = pd.DataFrame(cancel_grp.size()).rename(columns = {0:'total_cancelled_bookings'})

# Counting total number of bookings for each type of hotel
grouped_by_hotel = df.groupby('hotel')
total_booking = grouped_by_hotel.size()
D2 = pd.DataFrame(total_booking).rename(columns = {0: 'total_bookings'})
D3 = pd.concat([D1,D2], axis = 1)

# Calculating cancel percentage
D3['cancel_%'] = round((D3['total_cancelled_bookings']/D3['total_bookings'])*100,2)
D3
# Out:
#               total_cancelled_bookings  total_bookings  cancel_%
# hotel
# City Hotel                       16034           53273     30.10
# Resort Hotel                      7974           33956     23.48

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To know Which hotel has higher bookings cancellation rate.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Almost 30 % of City Hotel bookings got canceled.Almost 23 % of Resort Hotel bookings got canceled.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Approximately 30% of bookings in City Hotels and nearly 23% of bookings in Resort Hotels were canceled. This cancellation rate difference between the two types of hotels suggests a higher cancellation rate in City Hotels. Understanding and addressing the reasons behind cancellations in City Hotels could be crucial for optimizing revenue, enhancing customer satisfaction, and implementing strategies to mitigate cancellations. Additionally, exploring the factors contributing to the lower cancellation rate in Resort Hotels might provide insights into effective practices that could be applied more broadly.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Selecting and counting repeated customers bookings
repeated_data = df[df['is_repeated_guest'] == 1]
repeat_grp = repeated_data.groupby('hotel')
D1 = pd.DataFrame(repeat_grp.size()).rename(columns = {0:'total_repeated_guests'})

# Counting total bookings
total_booking = grouped_by_hotel.size()
D2 = pd.DataFrame(total_booking).rename(columns = {0: 'total_bookings'})
D3 = pd.concat([D1,D2], axis = 1)

# Calculating repeat %
D3['repeat_%'] = round((D3['total_repeated_guests']/D3['total_bookings'])*100,2)

plt.figure(figsize = (5,3))
sns.barplot(x = D3.index, y = D3['repeat_%'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To know Which hotel has high chance that its customer will return for another stay?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Both hotels have very small percentage that customer will repeat, but Resort hotel has slightly higher repeat % than City Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
group_by_dc = df.groupby('distribution_channel')
d2 = pd.DataFrame(round(group_by_dc['lead_time'].median(),2)).reset_index().rename(columns = {'lead_time': 'median_lead_time'})
plt.figure(figsize = (7,5))
sns.barplot(x = d2['distribution_channel'], y = d2['median_lead_time'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To know Which channel is mostly used for early booking of hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# TA/TO is mostly used for planning Hotel visits ahead of time. But for sudden visits other mediums are most preferred.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
d4 = pd.DataFrame(round((group_by_dc['days_in_waiting_list']).mean(),2)).reset_index().rename(columns = {'days_in_waiting_list': 'avg_waiting_time'})
plt.figure(figsize = (7,5))
sns.barplot(x = d4['distribution_channel'], y = d4['avg_waiting_time'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This will tell Which channel has longer average waiting time?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# While booking via TA/TO one may have to wait a little longer to confirm booking of rooms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
group_by_dc_hotel = df.groupby(['distribution_channel', 'hotel'])
d5 = pd.DataFrame(round((group_by_dc_hotel['adr']).agg(np.mean),2)).reset_index().rename(columns = {'adr': 'avg_adr'})
plt.figure(figsize = (7,5))
sns.barplot(x = d5['distribution_channel'], y = d5['avg_adr'], hue = d5['hotel'])
plt.ylim(40,140)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is taken in account to know Which distribution channel brings better revenue generating deals for hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# GDS channel brings higher revenue generating deals for City hotel, in contrast to that most bookings come via TA/TO. City Hotel can work to increase outreach on GDS channels to get more higher revenue generating deals.
#
# Resort hotel has more revnue generating deals by direct and TA/TO channel. Resort Hotel need to increase outreach on GDS channel to increase revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
d1 = pd.DataFrame((group_by_dc['is_canceled'].sum()/group_by_dc.size())*100).drop(index = 'Undefined').rename(columns = {0: 'Cancel_%'})
plt.figure(figsize = (10,5))
sns.barplot(x = d1.index, y = d1['Cancel_%'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to understand what causes the people to cancel the booking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# TA/TO has highest booking cancellation %. Therefore, a booking via TA/TO is 30% likely to get cancelled.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
waiting_bookings = df[df['days_in_waiting_list'] !=0]  # Selecting bookings with non zero waiting time


fig, axes = plt.subplots(1, 2, figsize=(18, 8))
sns.kdeplot(ax=axes[0],x = 'days_in_waiting_list', hue = 'is_canceled' , data = waiting_bookings)
sns.kdeplot(ax = axes[1], x = df['lead_time'], hue = df['is_canceled'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To see what causes the cancelation of bookings of rooms by customers

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We see that most of the bookings that are cancelled have waiting period of less 150 days but also most of bookings that are not cancelled also have waiting period less than 150 days. Hence this shows that waiting period has no effect on cancellation of bookings. \
# \
# Also, lead time has no affect on cancellation of bookings, as both curves of cancelation and not cncelation are similar for lead time too.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14

# %%
# chart 14 Visualisation code
def check_room_allot(x):
  if x['reserved_room_type'] != x['assigned_room_type']:
    return 1
  else:
    return 0

df['same_room_not_alloted'] = df.apply(lambda x : check_room_allot(x), axis = 1)
grp_by_canc = df.groupby('is_canceled')

D3 = pd.DataFrame((grp_by_canc['same_room_not_alloted'].sum()/grp_by_canc.size())*100).rename(columns = {0: 'same_room_not_alloted_%'})
plt.figure(figsize = (10,7))
sns.barplot(x = D3.index, y = D3['same_room_not_alloted_%'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Now we will check whether not getting allotted the same room type as demanded is the cause of cancellation fo bookings

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We see that not getting same room as demanded is not the case of cancellation of rooms. A significant percentage of bookings are not cancelled even after getting different room as demanded.

# %% [markdown]
# #### Chart - 15

# %%
# chart 15 visualization code
d1 = pd.DataFrame(df['agent'].value_counts()).reset_index().rename(columns = {'index':'agent','agent':'num_of_bookings'}).sort_values(by = 'num_of_bookings', ascending = False)
d1.drop(d1[d1['agent'] == 0].index, inplace = True)            # 0 represents that booking is not made by an agent
d1 = d1[:10]  # Selecting top 10 performing agents
plt.figure(figsize=(10, 5))
sns.barplot(x='agent', y='num_of_bookings', data=d1, order=d1.sort_values('num_of_bookings', ascending=False).agent)
# Out:
# <Axes: xlabel='agent', ylabel='num_of_bookings'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Which agent makes most no. of bookings?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Agent no. 9 has made most no. of bookings.

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8))

grp_by_room = df.groupby('assigned_room_type')
d1['Num_of_bookings'] = grp_by_room.size()

sns.countplot(ax = axes[0], x = df['assigned_room_type'])
sns.boxplot(ax = axes[1], x = df['assigned_room_type'], y = df['adr'])
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# To know Which agent makes most no. of bookings.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most demanded room type is A, but better adr rooms are of type H, G and C also. Hotels should increase the no. of room types A and H to maximise revenue.

# %%
grp_by_country = df.groupby('country')
d2 = pd.DataFrame(grp_by_country.size()).rename(columns = {0:'no. of bookings'}).sort_values('no. of bookings', ascending = False)
d2 = d2[:10]
sns.barplot(x = d2.index, y = d2['no. of bookings'])
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# To see from which countries most of the customers visit these hotels?

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the customers come from Portugal, Great Britain, France and Spain.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# The analysis reveals key insights into the hotel business, showcasing that City Hotel bookings dominate at over 60%, while Resort Hotel bookings constitute less than 40%. The median lead time is slightly higher for City hotels, indicating advanced planning by customers for their visits. Short stays of less than 4 days are prevalent, with guests favoring City hotels for such durations and Resort hotels for longer stays. Notably, the cancellation rates differ, with approximately 30% for City Hotels and nearly 23% for Resort Hotels. Moreover, City hotels experience significantly longer waiting times, suggesting heightened demand and busier operations compared to Resort hotels.
#
# To achieve business objectives, it is recommended to tailor marketing strategies and services based on observed stay length preferences, ensuring guest satisfaction and loyalty. Strategic resource allocation is crucial to optimize staffing and services dynamically, preventing underutilization in either hotel type. Efforts to enhance operational efficiency in City hotels should be prioritized to manage increased demand and waiting times effectively. Additionally, a detailed analysis of the reasons behind higher cancellation rates in City hotels can inform the implementation of strategies, such as personalized promotions or flexible cancellation policies, to mitigate cancellations. Staying agile in adapting marketing strategies to changing customer preferences and competitive dynamics will be essential for sustained competitiveness in the market. Continuous monitoring and adaptation to market trends are vital for achieving long-term success in the dynamic hospitality industry.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis provides valuable insights into the hotel business, highlighting the dominance of City Hotel bookings, stay length preferences, and operational dynamics. While City hotels experience higher demand and longer waiting times, Resort hotels cater to guests with longer stays. Understanding these patterns is crucial for tailoring marketing strategies, optimizing resource allocation, and enhancing overall customer satisfaction. The observed cancellation rates, with City hotels experiencing a higher percentage, necessitate targeted efforts to identify and address underlying reasons. Implementing strategies to mitigate cancellations, alongside operational efficiency improvements, will contribute to achieving business objectives. To ensure long-term success, it is imperative for the client to stay agile in adapting to market trends, monitor customer preferences, and maintain a competitive edge in the dynamic hospitality landscape.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
